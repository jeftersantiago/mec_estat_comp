# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Tarefa 1 $\mapsto$ Gráficos dos sinais

# %%
data = np.loadtxt("output-signal-A.dat")

plt.figure(figsize=(8, 8))
plt.plot(data[:,0], data[:,1], color='#b5b823', marker='o', linestyle='dashed', markersize=5, label = r'$a_1 = 2, a_2 = 4, \omega_1 = 4\pi(Hz), \omega_2 = 2.5\pi (Hz)$')

plt.xlim(0, 2.5 * np.pi)

plt.grid()
plt.xlabel("Tempo", fontsize=20)
plt.ylabel("Amplitude", fontsize=20)
plt.legend(fontsize=12)

plt.savefig("sinal-A.eps")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
data = np.loadtxt("output-signal-B.dat")

plt.figure(figsize=(8, 8))
plt.plot(data[:,0], data[:,1], color='#b5b823', marker='o', linestyle='dashed', markersize=5, label = r'$a_1 = 3, a_2 = 2, \omega_1 = 4\pi(Hz), \omega_2 = 2.5\pi (Hz)$')

plt.xlim(0, 2.5 * np.pi)

plt.xlabel("Tempo", fontsize=20)
plt.ylabel("Amplitude", fontsize=20)
plt.legend(fontsize=10)

plt.savefig("sinal-B.eps")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
data = np.loadtxt("output-signal-C.dat")

plt.figure(figsize=(8, 8))
plt.plot(data[:,0], data[:,1], color='#3ab541', marker='o', linestyle='dashed', markersize=5, label = r'$a_1 = 2, a_2 = 4, \omega_1 = 4\pi(Hz), \omega_2 = 0.2\pi (Hz)$')

plt.xlim(0, 30 * np.pi)
plt.xlabel("Tempo", fontsize=20)
plt.ylabel("Amplitude", fontsize=20)
plt.legend(fontsize=10)

plt.savefig("sinal-C.eps")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
data = np.loadtxt("output-signal-D.dat")

plt.figure(figsize=(8, 8))
plt.plot(data[:,0], data[:,1], color='#3ab541', marker='o', linestyle='dashed', markersize=5, label = r'$a_1 = 3, a_2 = 2, \omega_1 = 4\pi(Hz), \omega_2 = 0.2\pi (Hz)$')

plt.xlim(0, 30 * np.pi)
plt.xlabel("Tempo", fontsize=20)
plt.ylabel("Amplitude", fontsize=20)
plt.legend(fontsize=10)

plt.savefig("sinal-D.eps")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
data = np.loadtxt("output-signal-E.dat")

plt.figure(figsize=(8, 8))
plt.plot(data[:,0], data[:,1], color='#3171c4', marker='o', linestyle='dashed', markersize=5, label = r'$a_1 = 2, a_2 = 4, \omega_1 = 4\pi(Hz), \omega_2 = 1.4\pi (Hz)$')

plt.xlabel("Tempo", fontsize=20)
plt.ylabel("Amplitude", fontsize=20)
plt.legend(fontsize=10)

plt.savefig("sinal-E.eps")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
data = np.loadtxt("output-signal-F.dat")

plt.figure(figsize=(8, 8))
plt.plot(data[:,0], data[:,1], color='#3171c4', marker='o', linestyle='dashed', markersize=5, label = r'$a_1 = 2, a_2 = 4, \omega_1 = 4.2\pi(Hz), \omega_2 = 1;4\pi (Hz)$')

plt.xlabel("Tempo", fontsize=20)
plt.ylabel("Amplitude", fontsize=20)

plt.legend(fontsize=10)

plt.savefig("sinal-Feps")
plt.show()

# %% [markdown]
# ## Tarefa 2 $\mapsto$ Espectros das transformadas de Fourier

# %%
data = np.loadtxt("output-dft-A.dat")

plt.figure(figsize=(8, 8))
plt.plot(data[:,0], data[:,1], marker='o', markersize=0.2, label = "Cossenos")
plt.plot(data[:,0], data[:,2], marker='o', markersize=0.5, label = "Senos")

plt.grid()
plt.legend()
plt.show()

# %%
data = np.loadtxt("output-dft-B.dat")
data = np.loadtxt("output-dft-C.dat")
data = np.loadtxt("output-dft-D.dat")
data = np.loadtxt("output-dft-E.dat")
data = np.loadtxt("output-dft-F.dat")

# %% [markdown]
# ## Tarefa 3 $\mapsto$ Transformada de Fourier Inversa
